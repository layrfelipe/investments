# %%
import matplotlib.pyplot as plt
from Stocks import Stocks

stocks = Stocks()

# %%
from datetime import datetime
market_caps = stocks.get_sectors_market_cap()
market_caps.plot(kind='bar', figsize=(8, 5), legend=False)
plt.xlabel('Sectors', fontsize=10)
plt.ylabel('Market Cap (R$ trihões)', fontsize=10)
today = datetime.now().date().strftime('%d/%m/%y')
plt.title(f'Market Caps by Sectors ({today})', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.ylim(0, 3e12)
plt.tight_layout()
plt.show()

# %%
df_sectors_companies_amount = stocks.get_sectors_companies_amount()
df_sectors_companies_amount.set_index('sector', inplace=True)
df_sectors_companies_amount.plot(kind='bar', figsize=(8, 5), legend=False)
plt.xlabel('Sectors', fontsize=10)
plt.ylabel('N of companies', fontsize=10)
plt.title('Sectors companies', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
