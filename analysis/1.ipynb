# %%
import matplotlib.pyplot as plt
from Stocks import Stocks
# import pandas as pd
# import numpy as np

stocks = Stocks()

# %%
rates = stocks.get_growth_rates_by_sector()
rates.plot(kind='bar', figsize=(12, 6), legend=False)
plt.xlabel('Sectors', fontsize=10)
plt.ylabel('Growth', fontsize=10)
plt.title('Growth Rates by Sectors', fontsize=12)

# Rotate x labels
plt.xticks(rotation=45, ha='right')

# Add grid lines
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Show plot
plt.tight_layout()
plt.show()
